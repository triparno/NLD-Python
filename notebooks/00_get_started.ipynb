# %%
from google.colab import drive
drive.mount('/content/drive')

# set your course Drive folder (create once in Drive)
COURSE_DRIVE_DIR = '/content/drive/MyDrive/NLDPy'
import os
os.makedirs(COURSE_DRIVE_DIR, exist_ok=True)
print('Course Drive folder:', COURSE_DRIVE_DIR)

# %%
# !pip install numpy scipy matplotlib sympy jupyterlab jupyter nbformat nbconvert papermill
